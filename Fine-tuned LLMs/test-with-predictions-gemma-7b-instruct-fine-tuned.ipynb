# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("sg-server-write")

# %%
# test-with-predictions-gemma-7b-instruct-fine-tuned

model_id = 'gemma-7b-instruct'
model_type = 'fine-tuned'
model_name = "unsloth/gemma-7b-it-bnb-4bit"

# %%
# %%capture
# !mamba install --force-reinstall aiohttp -y
# !pip install -U "xformers<0.0.26" --index-url https://download.pytorch.org/whl/cu121
# !pip install "unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git"

# Temporary fix for https://github.com/huggingface/datasets/issues/6753
# !pip install datasets==2.16.0 fsspec==2023.10.0 gcsfs==2023.10.0

import os
os.environ["WANDB_DISABLED"] = "true"

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",
    "unsloth/gemma-7b-it-bnb-4bit", # Instruct version of Gemma 7b
    "unsloth/gemma-2b-bnb-4bit",
    "unsloth/gemma-2b-it-bnb-4bit", # Instruct version of Gemma 2b
] # More models at https://huggingface.co/unsloth
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2024-06-11 15:38:29.105986: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-11 15:38:29.106087: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-11 15:38:29.371551: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048 
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True 

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name, 
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    token = hf_token, 
)

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN

model = FastLanguageModel.get_peft_model(
    model,
    r = 16, 
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # 4x longer contexts auto supported!
    random_state = 3407,
    use_rslora = False,  # rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
# Out:
# config.json:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Gemma patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.2+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.25.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/5.57G [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/40.6k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# Unsloth 2024.5 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %%
# Inference Template
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) #+ EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

# %%
# Training Dataset preparation for Fine-Tuning
import pandas as pd
from datasets import Dataset
import os

# Load the dataset
p_train_df = pd.read_csv('/kaggle/input/symptom-disease-classification/train.csv')
p_train_df = p_train_df[['text', 'disease']]

# Perform transformations on p_train_df
p_train_df['text'] = "Patient's query or symptoms : " + p_train_df['text']
p_train_df['disease'] = "Identified Health Problem : " + p_train_df['disease']

# Rename columns
p_train_df = p_train_df.rename(columns={'text': 'input', 'disease': 'output'})

# Add new column 'instruction'
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")

p_train_df['instruction'] = instruction

# Reorder columns
p_train_df = p_train_df[['output', 'input', 'instruction']]

# Convert pandas DataFrame to Dataset
train_dataset = Dataset.from_pandas(p_train_df)

# Map the formatting function (assuming formatting_prompts_func is defined elsewhere)
train_dataset = train_dataset.map(formatting_prompts_func, batched=True)

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/train_dataset'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, 'transformed_train.csv')

# Save the DataFrame to CSV
p_train_df.to_csv(output_file, index=False)

# Display the file path
print("Saved transformed train dataset to:", output_file)
# Out:
# Map:   0%|          | 0/3259 [00:00<?, ? examples/s]
# Saved transformed train dataset to: /kaggle/working/train_dataset/transformed_train.csv

# %%
# Testing Dataset preparation for Fine-Tuning
import pandas as pd
from datasets import Dataset
import os

p_test_df = pd.read_csv('/kaggle/input/symptom-disease-classification/test_primary.csv')
p_test_df = p_test_df[['text','disease']]


# Perform transformations on p_test_df
p_test_df['text'] = "Patient's query or symptoms : " + p_test_df['text']
p_test_df['disease'] = "Identified Health Problem : " + p_test_df['disease']

# Rename columns
p_test_df = p_test_df.rename(columns={'text': 'input', 'disease': 'output'})

# Add new column 'instruction'
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")

p_test_df['instruction'] = instruction

p_test_df = p_test_df[['output','input','instruction']]

# Convert pandas DataFrame to Dataset
test_dataset = Dataset.from_pandas(p_test_df)

test_dataset = test_dataset.map(formatting_prompts_func, batched = True,)

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/test_dataset'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, 'transformed_test_primary.csv')

# Save the DataFrame to CSV
p_test_df.to_csv(output_file, index=False)

# Display the file path
print("Saved transformed test dataset to:", output_file)
# Out:
# Map:   0%|          | 0/618 [00:00<?, ? examples/s]
# Saved transformed test dataset to: /kaggle/working/test_dataset/transformed_test_primary.csv

# %% [markdown]
# #### Training for 2 epochs

# %%
# Calculate the number of steps per epoch
num_epochs = 2  # Assuming you want to train for 2 epochs
total_training_examples = len(train_dataset)  # Assuming dataset is the training dataset
batch_size = 2  # Assuming per_device_train_batch_size is set to 2
gradient_accumulation_steps = 4  # Assuming gradient_accumulation_steps is set to 4
steps_per_epoch = (total_training_examples / batch_size) / gradient_accumulation_steps

# Set the max_steps parameter based on the number of epochs
max_steps = int(steps_per_epoch * num_epochs)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset,
    eval_dataset = test_dataset, 
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = max_steps,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "/kaggle/working/",
        report_to = "none",
    ),
)
# Out:
# /opt/conda/lib/python3.10/site-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/3259 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/618 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 5.83 GB of memory reserved.

# %% [markdown]
# ## Training the Model

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 3,259 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 814
#  "-____-"     Number of trainable parameters = 50,003,968
#     <div>
#
#       <progress value='814' max='814' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [814/814 2:02:02, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>7.462100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.115200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.123800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.215700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.409500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.602100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.182800</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.539200</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.979800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.412600</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.135700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.424600</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.088500</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.109000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.857400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.874400</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.144200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.787300</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.669800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.587000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.454700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.451900</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.015700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.623700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.853000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.699500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.712500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.695600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.794000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.458000</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.872900</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.560600</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.588500</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.388400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.438800</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.061300</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.740100</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.573800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.577000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.514900</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.521900</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.781900</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.842600</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.537300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.551700</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.469500</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.577000</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.649400</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.750200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.633300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.364000</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.589300</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.851000</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.633000</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.683200</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.624900</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.369800</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.438900</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.395400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.805700</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.788800</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.868000</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.475400</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.801700</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.389400</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.566700</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.719600</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.398900</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.913000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.390700</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.615000</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.725900</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.318300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.721400</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.548200</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.798400</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.646000</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.618400</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.733400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.898000</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.447700</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.636700</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.469100</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.657700</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.731100</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.480400</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.582500</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.818000</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.553800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.672200</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.679100</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.479000</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.449600</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.514700</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.542700</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.756900</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.807100</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.403000</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.417700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.423200</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.612600</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.652900</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.581400</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.560200</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.479100</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.541200</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.667200</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.378500</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.528600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.579200</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.484700</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.627600</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.742700</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.410400</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.896800</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.463800</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.515400</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.781000</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.436000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.247800</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.562500</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.626800</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.660700</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.566800</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.457600</td>
#     </tr>
#     <tr>
#       <td>126<

# %% [markdown]
# # Saving the Fine-Tuned Lora Adaptors for Inferencing and Evaluation in Future

# %%
model.save_pretrained(f"/kaggle/working/fine-tuned-{model_id}-lora")

# %% [markdown]
# # Prediction or Test Inferencing on the Fine-Tuned Model

# %%
EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
# Setting the model for inference
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN


# generating response and cleaning it
def get_raw_response(instruction, input_text):
    inputs = tokenizer(
        [
            alpaca_prompt.format(
                f"{instruction}", # instruction
                f"{input_text}", # input
                "", # output - blank for generation!
            )
        ], return_tensors="pt").to("cuda")

    outputs = model.generate(**inputs, max_new_tokens=16, use_cache=True)
    raw_response = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return raw_response[0]

def get_response(instruction, input_text):
    raw_response = get_raw_response(instruction=instruction, input_text=input_text)
    # Extract Response from raw_response and return it as a string
    response = raw_response.split("### Response:\n")[1].strip()
    return response

# demo
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")
input_text = "Patient's query or symptoms : skin rash, blackheads, scarring"

print(get_response(instruction=instruction, input_text=input_text))
# Out:
# Identified Health Problem : Acne Vulgaris

# %%
# Function to generate prediction using get_response function
def generate_prediction(row):
    instruction = row['instruction']
    input_text = row['input']
    prediction = get_response(instruction=instruction, input_text=input_text)
    print(f'{model_type} {model_id} prediction ::--> ', prediction)
    return prediction

# Function to generate prediction using get_response function
def generate_prediction_chunk(chunk, batch_index, i):
    chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
    
    # Create the directory if it doesn't exist
    output_dir = '/kaggle/working/output/'
    os.makedirs(output_dir, exist_ok=True)

    # Define the file path
    output_file = os.path.join(output_dir, f'predictions-{model_id}-{model_type}_batch_{batch_index}_i={i}.csv')
    chunk.to_csv(output_file, index=False)

# Load the test.csv file
test_df = pd.read_csv('/kaggle/working/test_dataset/transformed_test_primary.csv')

# Apply the generate_prediction_chunk function to create the prediction column in batches
batch_size = 100
for i in range(0, len(test_df), batch_size):
    chunk = test_df.iloc[i:i+batch_size]
    generate_prediction_chunk(chunk, i // batch_size, i)
# Out:
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vertigo (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vertigo (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vertigo (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris (Acne)
# The most common acne symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Prone Skin (Aps) Psoriasis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris (Acne)
#
# ### Explanation:
# Acne
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris (Acne)
#
# The most common acne lesions
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris (Acne)
#
# The most common acne symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris (Acne)
#
# ### Explanation:
# Acne
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris (Acne)
#
# ### Explanation:
# Acne
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris (Acne)
#
# ### Explanation:
# Acne
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Acne Rosea
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Aids/hiv infection (hiv stds)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Aids Related Complex (arc)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis Cirrhosis (ahcc)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis Cirrhosis (ahcc)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis Cirrhosis (ahcc)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Bronchitis (cab) Allergy Asthma Bronchitis (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection (rhinovirus)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Hybrid (aoh) Syndrome
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Drug Reaction (Aadr) Aadr Aadr
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Bronchitis (cab) Allergy Asthma Bronchitis (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Bronchitis (cab) Allergy asthma bronchitis (cab
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Drug Reaction (aadr) Aadr Aadr
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms (conjunctivitis, hay fever, etc
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma And Anaphylaxis Asthma (aaa) Aasth
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Rhinitis (aor) Aor Aor
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma And Sinus Infection Complication (Aasc) Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy (hay fever) Symptoms of allergy (hay fever)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms (allergic rhinitis)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy (hay fever) And Anaphylaxis Symptoms Of Anaphylaxis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy (hay fever) Swelling caused by an allergy (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Drug Reaction (Aadr) Aadr Aadr
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy (hay fever) Symptoms of allergy (hay fever)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy (hay fever) Symptoms of allergy (hay fever)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection (rhinovirus)
#
# The common cold
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy (hay fever) Symptoms of allergy (hay fever)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy (hay fever) Symptoms of allergy (hay fever)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Anemia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Appendicitis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of Joints (oa)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of The Joints (oa)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of The Joints (oa)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of The Joints (oa)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of The Spine And Joints (oapsj
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of The Joints (oa)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains  Arthritis pains are caused by an inflammatory
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of Joints (oa)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of The Joints (oa)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains (oa)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains  Arthritis pains are caused by an inflammatory
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains Of The Joints (rheumatoid arthritis)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains In The Joints Of The Body
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Asthma Inhalers And Asthma Symptoms In Children And Adults With
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm) Bronchial
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronsospasmodic attack
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronspasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronspasm) Bronchial
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm) Bronchial
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronspasm) Bronchial
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronspasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronspasm) Bronchial
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchial Asthma Episode)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchial Asthma Episode) Bronchial
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronspasms) Bronchial
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchitis In Children And Adults With Chronic Lung Disease (cop
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bursitis Painful Bursitis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cancer Symptoms And Causes Cancer symptoms and causes vary widely from cancer
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Celiac Disease And Gluten Intolerance In Children And Adults
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Cancer Stage 0
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Movements Neck Pain
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Movements
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# /tmp/ipykernel_25/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Movements (cspn)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Syndrome (cspns)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Movements
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Movements (cspn)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Movements
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Movements (cspn)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck (cspn)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Pain Syndrome (csp)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Painful Neck Movements
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Virus (Varicella)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Varicella) Chicken Pox (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Rash Itch
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Rash Itch
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Virus Rash (varicella)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Virus Infection Chicken Pox Virus Infection Chicken P
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Virus (Varicella)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Virus Infection Chicken Pox Virus Infection Chicken P
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Varicella) Chicken Pox (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Virus Infection Chicken Pox Virus Infection Chicken P
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Chicken Pox Rash Itch
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Liver Disease (ccld)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Liver Disease (ccld)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Liver Disease (ccld)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Liver Disease (ccld)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Heart Disease Heart failure symptoms can vary from person to person.
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection (rhinovirus)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)  Bron
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms (congestion,runny nose,red eyes
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection (cvid)
# Common cold virus
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Strep Throat Bronchitis Bronchial Asthma
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Strep Throat Bronchitis Measles Chicken
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms (allergic rhinitis, sinusitis, asthma
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection (cvid)
#
# The common cold
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold (flu)
#
# The common cold is a viral
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Bronchitis Bronchial Asthma Bronchiolitis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Strep Throat Bronchitis Bronchial Asthma
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Strep Throat Bronchitis Bronchiolitis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection (rhinovirus)  Common cold symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection (cvid)
# Common cold virus
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Common Cold Virus Infection Symptoms
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dementia And Related Cognitive Disorders In Adults
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually appear 4
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually appear 4
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually appear 4
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four days
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox (Shingles) Chicken Pox (Sh
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually appear 4
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually appear 4
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually appear 4
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually begin about four to
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever symptoms usually appear 4
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Depression In Older Adults
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# /tmp/ipykernel_25/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (dm) Peripheral Neuropathies In dm peripheral
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (diabesity) Diabetes Mellitus (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Side Effects Drug Reaction (Id
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Psoriasis Thrombocytopenia (TTP
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 1
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (dm) Neuropathy In Diabetes (nid
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 1
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Symptoms In type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (dm) Diabetes Mellitus (dm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (type 2
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Symptoms In Diabetes Mellitus, your blood sugar
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease Peptic ulcer disease can cause:
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles) Fissure Anal
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)  Dimorphic hemor
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles) Fissure Rect
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)  Dimorphic hemor
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles) Fissure Rect
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)  Dimorphic hemor
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)  Dimorphic hemor
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)  Dimorphic hemor
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)  Dimorphic hemor
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Syndrome (Dids) In
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Angina Pectoris Symptoms Of Angina Pectoris
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Scabies Rash Syndrome (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Sids (A) S
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Symptoms Of Drug Reaction (Id
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Sids (Sids)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction Hypoglycemia Syndrome (drhs) Diabetes Drug Reaction
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Post-Exposure) Symptoms (Dresslers Syndrome
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (psoriasis)  Drug reaction psoriasis is a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction Extravasculare (Drev) Syndrome D
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Syndrome (Dids) In
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Syndrome (Drs) Syndrome
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction Associated Fever (Darf) Reaction (Darf
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction Psychosis DRP (Tdps) Symptoms Of
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr)  Drug reaction (Idr
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Side Effects Drug Reaction (Id
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Sids (Sids)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Syndrome (Drs) In
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Idr) Sigs And Symptoms Of Drug
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Anaphylaxis (Drea
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction Psychosis DRP (Tdps)  Drug
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Drug Reaction Skin Rash (Drsr) Psoriasis Ps
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Epilepsy Symptoms And Causes Of Epilepsy In Children And Adults
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Erectile Dysfunction Ed In men, the blood vessels supplying the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fibromyalgia Pain Syndrome Fibromalgia Pain Syndrome Fibromyalgia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Flu Virus Infection (influenza)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Food Poisoning Illness (foodborne Illness) Foodborne Illness
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Parts (tinea corporis) F
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Parts (tinea)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Athlete's Foot) Fungal infection
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Skin Yeast Infection Psoriasis Psoriasis is a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Athlete's Foot) Fungal infection
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection On Skin (Candidiasis) Fungal Infection
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Skin Yeast Infection Psoriasis Psoriasis Psoriasis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Psoriasis Fungal Infection Psoriasis is a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Psoriasis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Psoriasis Fungal Infection Psoriasis is a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body (Tinea Corporis) Fungal
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Parts (tinea corporis)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Psoriasis Fungal Infection Psoriasis is a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body (Tinea Corporis) Fungal
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Parts (tinea corporis)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Skin Yeast Infection (Candidiasis)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Stds Itch
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Parts (tinea)  Fungal
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body (Tinea Corporis) Fungal
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body (oncology)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis) Fungal infection (candid
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gallstones Pain Gallbladder Cancer
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroenteritis Due To Food Poisoning
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroenteritis
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd) Gastroes
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd) Heartburn
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd) Heartburn
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd) Heartburn
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# /tmp/ipykernel_25/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd) Gastroes
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd) Gastroes
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd) Heartburn
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gerd (Gastroesophageal Reflux Disease) Syndrome Complex (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease Gerd (gerd)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Gerd (Gastroesophageal Reflux Disease) Syndrome Complex
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Glaucoma
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Heart Attack (angina)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Heart Attack (STEMI)  Heart attack symptoms can vary
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Heart Attack (angina pectoris)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis A Virus Infection (HAV)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis A Virus Infection (HAV)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis A Virus Infection (HAV)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis A Virus Infection (HAV)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis B Virus Infection (hbv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis B Virus Infection (hbv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis B Virus Infection (hbv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis B Virus Infection (hbv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis C Virus Infection (Hcv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis C Virus Infection (Hcv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis C Virus Infection (Hcv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis D Virus Infection (hdv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis D Virus Infection (hdv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis D Virus Infection (hdv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis D Virus Infection (hdv)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis E Virus Infection (hev)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis E Virus Infection (hev)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis E Virus Infection (hev)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hepatitis E Virus Infection (hev)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)
# The symptoms of hypertension (hyper
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) Emergency
#
# ### Answer:
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)  Hypertension (hypertension)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)  Hypertension (hypertension)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)  Hypertension (hypertension)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)  Hypertension (hyper-TEN
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (hypertension)  Hypertension (hypertension)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
# Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)  Hypertension (high blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hyperthyroidism
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hyperthyroidism
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hyperthyroidism
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hyperthyroidism
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypoglycemia  The most common symptom of hypoglycemia is sha
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypoglycemia  The most common symptom of hypoglycemia is sha
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypoglycemia  The most common symptom of hypoglycemia is a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypoglycemia Hyperglycemia Psychosis (Hhpp) Hpp
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypothyroidism
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypothyroidism
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypothyroidism
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Hypothyroidism
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo  Impetigo signs and symptoms include:
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo Ulcerated Healing Wounds On Face And Nose
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (infected skin) Fungal Infection Im
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection) Impetigo (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo Ulcerated  Impetigo is a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo Chronicus (Impetigo) Fungal
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (skin infection)  Impetigo (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo  Impetigo signs and symptoms include:
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo Infection Impetigo infection Impetigo is
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo Bullous (Impetigo) Abscess
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo Ulcerated  Impetigo is a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection)  Impetigo
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection) Impetigo (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo (staph infection) Impetigo (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice (yellow fever)  Jaundice (yellow fever
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice (yellow fever)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice (yellow fever)  Jaundice (yellow fever
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice (yellow fever)  Jaundice (yellow fever
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice (yellowing of the skin)  Jaundice
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Jaundice (yellow fever)
# ...
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia
# /tmp/ipykernel_25/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia Infection Bronchial Asthma Pneumonia Bronchial Asthma Pneumonia  Pneum
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack (bronchospasm)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia Phlegm
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia With Blood Clots In Lung (Pnbcl)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia With Blood Clots In Lungs (Pcls)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Prostate Cancer In Men With Bph Symptoms Or Other Prostate Cancer
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that causes skin
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Rash Psoriasis is a chronic autoimmune disease that causes
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Arthritis Pains (oa)  Arthritis pains (OA
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Rash Psoriasis is a chronic autoimmune disease that causes
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chronic autoimmune disease that affects the
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Chicken Pox Virus (Varicella Zoster Virus)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Insect Stinger Allergy (Anaphylaxis) Bites
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Rheumatoid Arthritis Pain Relief Specialist Dr. MCX  Rhe
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection caused by
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Shingles Pain Rash Itch
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease Peptic ulcer disease is a condition
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Stroke
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Thyroid Cancer
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection that affects
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection caused by
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection that affects
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid Fever (typhus)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection caused by
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may begin 3
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection caused by
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection caused by
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection caused by
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection caused by
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is a bacterial infection caused by
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever symptoms may include:  High
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease Of The Colon (Puuc)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Caused By E. Coli
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Caused By E. Coli
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) And Migraine Headache Disorder (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In women, a urinary tract
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) With a urinary tract infection (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)  A urinary tract infection (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)  A urinary tract infection (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)  A urinary tract infection (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In Children In adults, a
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In women, a urinary tract
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)  A urinary tract infection (
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Varicose veins in the legs are
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs  Varicose veins on the legs
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Veins Varicose Veins Legs
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Veins on the calf  Var
# /tmp/ipykernel_25/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Veins Varicose Veins On
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Varicose veins on the legs are
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Varicose veins on the legs are
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Varicose veins on the legs are
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Varicose veins on the legs are
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs  Varicose veins are swollen,
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Varicose veins on the legs are
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Legs Varicose veins on the legs are
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are swollen, twisted blood
# fine-tuned gemma-7b-instruct prediction ::-->  Identified Health Problem : Impetigo Venerealis (std) Itchiness
# /tmp/ipykernel_25/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)

# %%
import os
import pandas as pd

# Directory containing the CSV files
directory = '/kaggle/working/output/'

# List of file names to merge
file_names = [
    f"predictions-{model_id}-{model_type}_batch_0_i=0.csv",
    f"predictions-{model_id}-{model_type}_batch_1_i=100.csv",
    f"predictions-{model_id}-{model_type}_batch_2_i=200.csv",
    f"predictions-{model_id}-{model_type}_batch_3_i=300.csv",
    f"predictions-{model_id}-{model_type}_batch_4_i=400.csv",
    f"predictions-{model_id}-{model_type}_batch_5_i=500.csv",
    f"predictions-{model_id}-{model_type}_batch_6_i=600.csv"
]

# Initialize an empty DataFrame to store the merged data
merged_df = pd.DataFrame()

# Merge the CSV files in sequence
for file_name in file_names:
    file_path = os.path.join(directory, file_name)
    df = pd.read_csv(file_path)
    merged_df = pd.concat([merged_df, df], ignore_index=True)
merged_df = merged_df[['output','prediction','input','instruction']]

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/results/'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, f"predictions-{model_id}-{model_type}-output.csv")

# Save the merged DataFrame to a new CSV file
merged_df.to_csv(output_file, index=False)
