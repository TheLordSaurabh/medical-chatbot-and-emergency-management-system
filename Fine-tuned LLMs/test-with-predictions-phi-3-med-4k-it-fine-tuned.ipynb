# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("sg-server-write")

# %%
# test-with-predictions-unsloth/Phi-3-medium-4k-it-fine-tuned

model_id = 'Phi-3-medium-4k-instruct'
model_type = 'fine-tuned'
model_name = "unsloth/Phi-3-medium-4k-instruct-bnb-4bit"

# %%
# %%capture
# !mamba install --force-reinstall aiohttp -y
# !pip install -U "xformers<0.0.26" --index-url https://download.pytorch.org/whl/cu121
# !pip install "unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git"

# Temporary fix for https://github.com/huggingface/datasets/issues/6753
# !pip install datasets==2.16.0 fsspec==2023.10.0 gcsfs==2023.10.0

import os
os.environ["WANDB_DISABLED"] = "true"

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",
    "unsloth/gemma-7b-it-bnb-4bit", # Instruct version of Gemma 7b
    "unsloth/gemma-2b-bnb-4bit",
    "unsloth/gemma-2b-it-bnb-4bit", # Instruct version of Gemma 2b
] # More models at https://huggingface.co/unsloth
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2024-06-11 15:31:43.514865: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-11 15:31:43.514988: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-11 15:31:43.686929: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048 
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True 

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name, 
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    token = hf_token, 
)

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN

model = FastLanguageModel.get_peft_model(
    model,
    r = 16, 
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # 4x longer contexts auto supported!
    random_state = 3407,
    use_rslora = False,  # rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
# Out:
# config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Mistral patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.2+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.25.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors.index.json:   0%|          | 0.00/165k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.72G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Unsloth 2024.5 patched 40 layers with 40 QKV layers, 40 O layers and 40 MLP layers.

# %%
# Inference Template
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) #+ EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

# %%
# Training Dataset preparation for Fine-Tuning
import pandas as pd
from datasets import Dataset
import os

# Load the dataset
p_train_df = pd.read_csv('/kaggle/input/symptom-disease-classification/train.csv')
p_train_df = p_train_df[['text', 'disease']]

# Perform transformations on p_train_df
p_train_df['text'] = "Patient's query or symptoms : " + p_train_df['text']
p_train_df['disease'] = "Identified Health Problem : " + p_train_df['disease']

# Rename columns
p_train_df = p_train_df.rename(columns={'text': 'input', 'disease': 'output'})

# Add new column 'instruction'
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")

p_train_df['instruction'] = instruction

# Reorder columns
p_train_df = p_train_df[['output', 'input', 'instruction']]

# Convert pandas DataFrame to Dataset
train_dataset = Dataset.from_pandas(p_train_df)

# Map the formatting function (assuming formatting_prompts_func is defined elsewhere)
train_dataset = train_dataset.map(formatting_prompts_func, batched=True)

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/train_dataset'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, 'transformed_train.csv')

# Save the DataFrame to CSV
p_train_df.to_csv(output_file, index=False)

# Display the file path
print("Saved transformed train dataset to:", output_file)
# Out:
# Map:   0%|          | 0/3259 [00:00<?, ? examples/s]
# Saved transformed train dataset to: /kaggle/working/train_dataset/transformed_train.csv

# %%
# Testing Dataset preparation for Fine-Tuning
import pandas as pd
from datasets import Dataset
import os

p_test_df = pd.read_csv('/kaggle/input/symptom-disease-classification/test_primary.csv')
p_test_df = p_test_df[['text','disease']]


# Perform transformations on p_test_df
p_test_df['text'] = "Patient's query or symptoms : " + p_test_df['text']
p_test_df['disease'] = "Identified Health Problem : " + p_test_df['disease']

# Rename columns
p_test_df = p_test_df.rename(columns={'text': 'input', 'disease': 'output'})

# Add new column 'instruction'
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")

p_test_df['instruction'] = instruction

p_test_df = p_test_df[['output','input','instruction']]

# Convert pandas DataFrame to Dataset
test_dataset = Dataset.from_pandas(p_test_df)

test_dataset = test_dataset.map(formatting_prompts_func, batched = True,)

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/test_dataset'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, 'transformed_test_primary.csv')

# Save the DataFrame to CSV
p_test_df.to_csv(output_file, index=False)

# Display the file path
print("Saved transformed test dataset to:", output_file)
# Out:
# Map:   0%|          | 0/618 [00:00<?, ? examples/s]
# Saved transformed test dataset to: /kaggle/working/test_dataset/transformed_test_primary.csv

# %% [markdown]
# #### Training for 2 epochs

# %%
# Calculate the number of steps per epoch
num_epochs = 2  # Assuming you want to train for 2 epochs
total_training_examples = len(train_dataset)  # Assuming dataset is the training dataset
batch_size = 2  # Assuming per_device_train_batch_size is set to 2
gradient_accumulation_steps = 4  # Assuming gradient_accumulation_steps is set to 4
steps_per_epoch = (total_training_examples / batch_size) / gradient_accumulation_steps

# Set the max_steps parameter based on the number of epochs
max_steps = int(steps_per_epoch * num_epochs)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset,
    eval_dataset = test_dataset, 
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = max_steps,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "/kaggle/working/",
        report_to = "none",
    ),
)
# Out:
# /opt/conda/lib/python3.10/site-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/3259 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/618 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 7.504 GB of memory reserved.

# %% [markdown]
# ## Training the Model

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 3,259 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 814
#  "-____-"     Number of trainable parameters = 65,536,000
#     <div>
#
#       <progress value='814' max='814' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [814/814 3:14:53, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.134700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.037100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.088200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.819500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.402000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.579800</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.520700</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.405900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.235900</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.188900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.113800</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.913100</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.855100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.745400</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.550000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.549600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.513700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.460500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.429100</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.365000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.370900</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.580700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.434100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.524700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.466500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.470100</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.510700</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.529000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.384600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.585200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.431100</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.407600</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.349800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.357000</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.615100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.516300</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.449000</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.463200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.386400</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.408500</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.427700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.523200</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.388300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.363000</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.369500</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.410200</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.456900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.493000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.437000</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.307800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.403000</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.552100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.449500</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.484100</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.420800</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.321400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.395100</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.345400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.506400</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.539500</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.546000</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.420800</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.489400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.329000</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.412200</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.524700</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.367200</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.696300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.304500</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.385200</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.463400</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.277300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.478800</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.416200</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.503500</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.523900</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.484600</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.532000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.542100</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.414500</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.426800</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.357500</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.445400</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.514600</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.363300</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.439300</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.506000</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.429100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.429100</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.496100</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.374600</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.329900</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.382300</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.392700</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.498700</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.579300</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.327200</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.319800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.295900</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.400800</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.452400</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.394800</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.424200</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.369200</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.386800</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.496200</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.337700</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.380600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.447200</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.360300</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.439000</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.486100</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.347800</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.561100</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.343600</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.391200</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.510700</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.349600</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.235400</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.408500</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.438800</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.478700</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.429300</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.384600</td>
#     </tr>
#     <tr>
#       <td>126<

# %% [markdown]
# # Saving the Fine-Tuned Lora Adaptors for Inferencing and Evaluation in Future

# %%
model.save_pretrained(f"/kaggle/working/fine-tuned-{model_id}-lora")

# %% [markdown]
# # Prediction or Test Inferencing on the Fine-Tuned Model

# %%
EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
# Setting the model for inference
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN


# generating response and cleaning it
def get_raw_response(instruction, input_text):
    inputs = tokenizer(
        [
            alpaca_prompt.format(
                f"{instruction}", # instruction
                f"{input_text}", # input
                "", # output - blank for generation!
            )
        ], return_tensors="pt").to("cuda")

    outputs = model.generate(**inputs, max_new_tokens=16, use_cache=True)
    raw_response = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return raw_response[0]

def get_response(instruction, input_text):
    raw_response = get_raw_response(instruction=instruction, input_text=input_text)
    # Extract Response from raw_response and return it as a string
    response = raw_response.split("### Response:\n")[1].strip()
    return response

# demo
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")
input_text = "Patient's query or symptoms : skin rash, blackheads, scarring"

print(get_response(instruction=instruction, input_text=input_text))
# Out:
# Identified Health Problem : Acne Vulgaris (Acne) (

# %%
# Function to generate prediction using get_response function
def generate_prediction(row):
    instruction = row['instruction']
    input_text = row['input']
    prediction = get_response(instruction=instruction, input_text=input_text)
    print(f'{model_type} {model_id} prediction ::--> ', prediction)
    return prediction

# Function to generate prediction using get_response function
def generate_prediction_chunk(chunk, batch_index, i):
    chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
    
    # Create the directory if it doesn't exist
    output_dir = '/kaggle/working/output/'
    os.makedirs(output_dir, exist_ok=True)

    # Define the file path
    output_file = os.path.join(output_dir, f'predictions-{model_id}-{model_type}_batch_{batch_index}_i={i}.csv')
    chunk.to_csv(output_file, index=False)

# Load the test.csv file
test_df = pd.read_csv('/kaggle/working/test_dataset/transformed_test_primary.csv')

# Apply the generate_prediction_chunk function to create the prediction column in batches
batch_size = 100
for i in range(0, len(test_df), batch_size):
    chunk = test_df.iloc[i:i+batch_size]
    generate_prediction_chunk(chunk, i // batch_size, i)
# Out:
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vert
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vert
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vert
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Pimples Blackheads Pus-
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne, Blackheads (comedones)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Rosacea Pimples And Blackhead
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Pimples Blackheads Pus-
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Pimples Filled With Pus And
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo (Impetigo) Impetigo
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Vulgaris Pimples And Black
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Pimples Blackheads Scurf
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Pimples Blackheads Body Acne
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Pimples Blackheads Body Acne
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo (Impetigo) Impetigo
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Acne Pimples Blackheads Pus-
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Aids ( Hiv ) ( Aids ) By
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Aids (acquired immunodeficiency synd
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis Alcoholic
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis (AH)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis, Alcohol
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis Alcoholic
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms Chills, vomiting
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu (Influenza) Common
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Allergy Asth
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Drug Reaction
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms Can Be Similar to COVID
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms Chills, vomiting
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Drug Reaction Drug Reaction
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms And Allergy Rh
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Allergy Asth
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Migraine Headache
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms Can Vary Depending on
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Drug Reaction (Allergy
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms And Allergy Rh
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Rhinitis (Allergic Rh
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms
#
# You are experien
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Asthma Drug Reaction D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Reaction (Allergy) All
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Drug Reaction Drug Reaction
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms       Open pop-up
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms Can Vary Depending on
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy
#
# ### Instruction:
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Allergy Symptoms Chills, vomiting
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Iron Deficiency Anemia Carefully listen to the
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Appendicitis Carefully listen to the Patient'
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Psoriasis Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Painful Joints Ar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Painful Arthritis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Pain Management Arthritis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Pain Management Arthritis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Psoriasis Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Psoriasis Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis (Arthritis) Ar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Painful joints have been
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis (Osteoarthristis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Pain Management Arthritis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Psoriasis Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Arthritis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Psoriasis Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Psoriasis Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Psoriasis Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Osteoarthristis Carefully listen to the
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis (osteoarthristis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Painful Joints Ar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Pain And Stiffness J
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Painful Joints Ar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Asthma Care
#
# ### Instruction:
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma (Allergy)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma (Childhood Asth
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma (Asthma
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma (Childhood Asth
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchitis,
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma (Childhood Asth
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchitis,
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchitis, Chronic Bronchitis, Ac
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bursitis Carefully listen to the Patient'
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cancer Carefully listen to the Patient's
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Celiac Disease Celiac Disease Care
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Cancer Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis(Neck Ar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Carefully listen to
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Cervical Sp
# /tmp/ipykernel_24/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis (Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Cervical Sp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis(Neck Ar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Carefully listen to
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Carefully listen to
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Cervical Sp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Cervical Sp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Cervical Sp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis (Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Carefully listen to
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Cervical Sp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Cervical Sp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Carefully listen to
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Carefully listen to
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis (Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis (Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis (Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis (Arthrit
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis Cervical Sp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox Chicken Pox is a common
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever       Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue Fever D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Chicken Pox Chicken
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Chicken Pox Chicken
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever       Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Apart from the symptoms
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever (Dengue Hemor
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Chicken Pox Chicken
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox Chicken Pox Chicken P
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox Chicken Pox Chicken P
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis       Open pop-up
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Of Infancy Jau
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis       (Jaund
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Of Infancy Jau
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Kidney Disease (Chronic Kidney D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold Or Allergy Reaction Or Sinus
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu Common cold and flu are resp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu (Influenza) A
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold (Allergy) Allergy All
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu (Influenza) A
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Common Cold       Common Cold       Common Cold
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Common Cold       Common Cold       Common Cold
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu Common cold and flu are resp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu Common cold and flu are resp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu (Influenza) A
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu Symptoms Of common cold
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu (Influenza) A
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu Common cold and flu are resp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Common Cold And Flu Common cold and flu symptoms
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dementia Carefully listen to the Patient'
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever       Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue Fever D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever       Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue Fever D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Apart from the symptoms
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever       Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Chicken Pox Chicken
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Chicken Pox Chicken
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever       Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever       Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue Fever D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever (Dengue) D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever       Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever Dengue Fever D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dengue Fever (Dengue Hemor
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Depression Carefully listen to the Patient's
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# /tmp/ipykernel_24/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 The
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 The
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus (Type 2
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 The
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 The
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 The
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 The
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction        Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 The
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diabetes Mellitus Type 2 (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Diarrhea (loose, watery st
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids(piles)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction        Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction        Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction Change In Women's Horm
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Drug Reaction) Ch
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction     Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction Syndrome Drug Reaction
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction        Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction        Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction or Side Effects (Drug
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction (Adverse Effect) Drug
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction        Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction        Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction Change In Menstrual Cycle
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction Syndrome Drug Reaction
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction        Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Epilepsy Carefully listen to the Patient
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Erectile Dysfunction (ED)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fever (Chills, Headache, Nause
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fibromyalgia Syndrome Carefully listen
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Flu Symptoms And Complications Of The Fl
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Food Poisoning (Botulism) (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection, Drug Reaction,
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection, Chicken Pox,
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection, Drug Reaction,
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Lice       Open pop
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection, Dengue Fever
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Lice       Open pop
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Lice       Open pop
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection Body Lumps And Knot
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Tinea Versicolor
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Fungal Infection (Candidiasis)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gallstones Symptoms Of Gallstones P
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroenteritis (GI) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroenteritis (GI) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease (PUD)
# /tmp/ipykernel_24/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gerd (gastroesophageal refl
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Gerd (gastroesophageal refl
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Glaucoma Suspects Carefully listen to
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Heart Attack (Myocardial Infarction
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Heart Attack (Myocardial Infarction
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Heart Attack (Myocardial Infarction
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis A (Ai) Hepatitis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis A (Infectious Hepatitis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis A (Ai) Hepatitis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis A (Ai) Hepatitis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis B And C (Hepatitis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis B And C (Hepatitis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis B And C (Hepatitis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis B And C (Hepatitis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis C (Hep C) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis C (Hep C) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis C (Hep C) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis D (HDV) Infection (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis D (HDV) Infection (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis D (HDV) Infection (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis D (HDV) Infection (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis E (HEV) Infection (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis E (Jaundice) (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis E (Hepatitis E)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hepatitis E (HEV) Infection (
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) Malignant
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# Ex
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# Ex
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) The symptoms
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# ##
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# Ex
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (High Blood Pressure) Headache
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) The symptoms
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# Ex
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# You
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) Malignant
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# You
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# Ex
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# Ex
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (High Blood Pressure) Headache
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) is a common
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# Ex
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure)
#
# Ex
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) Hypertension
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) Headache,
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) The symptoms
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) Hypertension
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypertension (high blood pressure) The symptoms
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hyperthyroidism (Graves' Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hyperthyroidism (Graves' Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hyperthyroidism (Graves' Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hyperthyroidism (Graves' Dise
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypoglycemia (Low Blood Sugar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypoglycemia (Low Blood Sugar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypoglycemia (Low Blood Sugar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypoglycemia (Low Blood Sugar
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypothyroidism (Hashimoto's Th
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypothyroidism Diagnosis of hypothyroid
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypothyroidism Diagnosis of hypothyroid
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Hypothyroidism Diagnosis of hypothyroid
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Antibiotics are used to treat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Drug Reaction Impetigo is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Antibiotic Impetigo Imp
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Drug Reaction Impetigo is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Impetigo Impetigo Impetigo Impet
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice And Chronic Cholestasis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice Parents of children with jau
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice Parents of children with jau
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice Parents of children with jau
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice With Chills And Fever In
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice Parents of children with jau
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice With Parasites (Kala
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice And Chronic Cholestasis
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Jaundice (Yellowing Of The Sk
# /tmp/ipykernel_24/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia (Pneumonia) Pneumonia
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Pneumonia Pneumonia is an
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Pneumonia is an infection that
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia (Bacterial) Pneumonia
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia (Bacterial) Pneumonia
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia       Open pop-up dialog box
# /tmp/ipykernel_24/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia
#
# Explanation: The sympt
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Bronchial Asthma, Bronchial Ast
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Pneumonia is an infection that
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Pneumonia is an infection that
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia
#
# ### Instruction:
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Drug Reaction Pneumonia D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia The symptoms you are describing, such
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Pneumonia is an infection that
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Pneumonia Pneumonia Pneum
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Atypical Pneumonia Pneum
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Pneumonia Atypical Pneumonia Pneum
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Prostate Cancer Carefully listen to the Patient
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis can cause skin
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chron
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a skin
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis can occur anywhere
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Carefully listen to the Patient
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis       Psor
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis is a chron
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Carefully listen to the Patient
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Arthritis Pain And Stiffness In
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Carefully listen to the Patient
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Carefully listen to the Patient
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia and
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Around Eyes, Mouth
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Psoriasis Psoriasis Psorias
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Chicken Pox       Open pop-up dialog box
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Rabies       Open pop-up dialog box          Close
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Rheumatoid Arthritis Carefully
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever (Typhoid) Ty
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Shingles (Herpes Zoster) (Sh
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease (PUD)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Stroke Carefully listen to the Patient's
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Thyroid Cancer (Malignant) Th
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb) (tb)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
#
# Explan
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
#
# ###
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
#
# ###
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Typhoid Fever Typhoid fever is
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Crohn's Disease (Crohn
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection(uti) And D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Signs
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) And Kid
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection(uti) And Kid
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection(uti) Sympt
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) (uti
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Drug
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection(s) (uti
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) And D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) And Py
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Drug
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Drug
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection Uti )
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) And Py
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection(uti) And D
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) A ur
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Drug
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Infection
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Drug
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) Drug
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins And Spider Veins Varic
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins (Varicose Veins
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# /tmp/ipykernel_24/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins And Spider Veins Varic
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins (Varicose Veins
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins And Varicose Veins
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Carefully listen to the Pat
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins (Spider Veins)
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins And Spider Veins Varic
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Varicose Veins Varicose veins are
# fine-tuned Phi-3-medium-4k-instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And
# /tmp/ipykernel_24/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)

# %%
import os
import pandas as pd

# Directory containing the CSV files
directory = '/kaggle/working/output/'

# List of file names to merge
file_names = [
    f"predictions-{model_id}-{model_type}_batch_0_i=0.csv",
    f"predictions-{model_id}-{model_type}_batch_1_i=100.csv",
    f"predictions-{model_id}-{model_type}_batch_2_i=200.csv",
    f"predictions-{model_id}-{model_type}_batch_3_i=300.csv",
    f"predictions-{model_id}-{model_type}_batch_4_i=400.csv",
    f"predictions-{model_id}-{model_type}_batch_5_i=500.csv",
    f"predictions-{model_id}-{model_type}_batch_6_i=600.csv"
]

# Initialize an empty DataFrame to store the merged data
merged_df = pd.DataFrame()

# Merge the CSV files in sequence
for file_name in file_names:
    file_path = os.path.join(directory, file_name)
    df = pd.read_csv(file_path)
    merged_df = pd.concat([merged_df, df], ignore_index=True)
merged_df = merged_df[['output','prediction','input','instruction']]

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/results/'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, f"predictions-{model_id}-{model_type}-output.csv")

# Save the merged DataFrame to a new CSV file
merged_df.to_csv(output_file, index=False)
