# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("sg-server-write")

# %%
# test-with-predictions-Qwen2-7B-Instruct-fine-tuned

model_id = 'Qwen2-7B-Instruct'
model_type = 'fine-tuned'
model_name = "unsloth/Qwen2-7B-Instruct-bnb-4bit"

# %%
# %%capture
# !mamba install --force-reinstall aiohttp -y
# !pip install -U "xformers<0.0.26" --index-url https://download.pytorch.org/whl/cu121
# !pip install "unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git"

# Temporary fix for https://github.com/huggingface/datasets/issues/6753
# !pip install datasets==2.16.0 fsspec==2023.10.0 gcsfs==2023.10.0

import os
os.environ["WANDB_DISABLED"] = "true"

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",
    "unsloth/gemma-7b-it-bnb-4bit", # Instruct version of Gemma 7b
    "unsloth/gemma-2b-bnb-4bit",
    "unsloth/gemma-2b-it-bnb-4bit", # Instruct version of Gemma 2b
] # More models at https://huggingface.co/unsloth
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2024-06-11 15:25:33.942968: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-11 15:25:33.943065: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-11 15:25:34.075100: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048 
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True 

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name, 
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    token = hf_token, 
)

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN

model = FastLanguageModel.get_peft_model(
    model,
    r = 16, 
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # 4x longer contexts auto supported!
    random_state = 3407,
    use_rslora = False,  # rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
# Out:
# config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Qwen2 patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.2+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.25.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/5.55G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/80.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/367 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Unsloth 2024.5 patched 28 layers with 0 QKV layers, 28 O layers and 28 MLP layers.

# %%
# Inference Template
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) #+ EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

# %%
# Training Dataset preparation for Fine-Tuning
import pandas as pd
from datasets import Dataset
import os

# Load the dataset
p_train_df = pd.read_csv('/kaggle/input/symptom-disease-classification/train.csv')
p_train_df = p_train_df[['text', 'disease']]

# Perform transformations on p_train_df
p_train_df['text'] = "Patient's query or symptoms : " + p_train_df['text']
p_train_df['disease'] = "Identified Health Problem : " + p_train_df['disease']

# Rename columns
p_train_df = p_train_df.rename(columns={'text': 'input', 'disease': 'output'})

# Add new column 'instruction'
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")

p_train_df['instruction'] = instruction

# Reorder columns
p_train_df = p_train_df[['output', 'input', 'instruction']]

# Convert pandas DataFrame to Dataset
train_dataset = Dataset.from_pandas(p_train_df)

# Map the formatting function (assuming formatting_prompts_func is defined elsewhere)
train_dataset = train_dataset.map(formatting_prompts_func, batched=True)

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/train_dataset'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, 'transformed_train.csv')

# Save the DataFrame to CSV
p_train_df.to_csv(output_file, index=False)

# Display the file path
print("Saved transformed train dataset to:", output_file)
# Out:
# Map:   0%|          | 0/3259 [00:00<?, ? examples/s]
# Saved transformed train dataset to: /kaggle/working/train_dataset/transformed_train.csv

# %%
# Testing Dataset preparation for Fine-Tuning
import pandas as pd
from datasets import Dataset
import os

p_test_df = pd.read_csv('/kaggle/input/symptom-disease-classification/test_primary.csv')
p_test_df = p_test_df[['text','disease']]


# Perform transformations on p_test_df
p_test_df['text'] = "Patient's query or symptoms : " + p_test_df['text']
p_test_df['disease'] = "Identified Health Problem : " + p_test_df['disease']

# Rename columns
p_test_df = p_test_df.rename(columns={'text': 'input', 'disease': 'output'})

# Add new column 'instruction'
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")

p_test_df['instruction'] = instruction

p_test_df = p_test_df[['output','input','instruction']]

# Convert pandas DataFrame to Dataset
test_dataset = Dataset.from_pandas(p_test_df)

test_dataset = test_dataset.map(formatting_prompts_func, batched = True,)

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/test_dataset'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, 'transformed_test_primary.csv')

# Save the DataFrame to CSV
p_test_df.to_csv(output_file, index=False)

# Display the file path
print("Saved transformed test dataset to:", output_file)
# Out:
# Map:   0%|          | 0/618 [00:00<?, ? examples/s]
# Saved transformed test dataset to: /kaggle/working/test_dataset/transformed_test_primary.csv

# %% [markdown]
# #### Training for 2 epochs

# %%
# Calculate the number of steps per epoch
num_epochs = 2  # Assuming you want to train for 2 epochs
total_training_examples = len(train_dataset)  # Assuming dataset is the training dataset
batch_size = 2  # Assuming per_device_train_batch_size is set to 2
gradient_accumulation_steps = 4  # Assuming gradient_accumulation_steps is set to 4
steps_per_epoch = (total_training_examples / batch_size) / gradient_accumulation_steps

# Set the max_steps parameter based on the number of epochs
max_steps = int(steps_per_epoch * num_epochs)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset,
    eval_dataset = test_dataset, 
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = max_steps,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "/kaggle/working/",
        report_to = "none",
    ),
)
# Out:
# /opt/conda/lib/python3.10/site-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/3259 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/618 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 5.764 GB of memory reserved.

# %% [markdown]
# ## Training the Model

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 3,259 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 814
#  "-____-"     Number of trainable parameters = 40,370,176
#     <div>
#
#       <progress value='814' max='814' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [814/814 1:42:09, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.463400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.369900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.369800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.137600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.681200</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.862900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.659900</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.493400</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.158700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.102300</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.113700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.786500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.816500</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.864800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.702400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.699500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.952900</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.647300</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.594500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.533600</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.429400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.454700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.849100</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.553100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.707700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.605700</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.613900</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.646000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.712500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.446300</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.744200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.536300</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.545300</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.397800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.441300</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.890800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.670800</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.551900</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.557100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.480500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.491400</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.676700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.780900</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.494900</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.494500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.457900</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.541100</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.619900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.668600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.570300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.374600</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.546100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.799200</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.606800</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.636900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.567900</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.388000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.464300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.410800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.718200</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.711000</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.778600</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.510200</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.728500</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.402400</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.533200</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.692500</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.440800</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.862800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.396800</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.570600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.667800</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.326000</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.667000</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.504000</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.719900</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.650200</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.624500</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.666200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.773700</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.507600</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.601900</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.451000</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.618300</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.697400</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.491900</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.563600</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.742000</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.548800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.624200</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.669400</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.447200</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.469300</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.494200</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.526600</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.679900</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.766600</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.416700</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.424300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.423700</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.551100</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.614500</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.551400</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.522500</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.507600</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.489100</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.644200</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.406400</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.519600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.564200</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.476400</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.592000</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.659700</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.418000</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.817600</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.461200</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.526600</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.707500</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.458900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.264400</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.559200</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.590300</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.634000</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.563600</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.475900</td>
#     </tr>
#     <tr>
#       <td>126<

# %% [markdown]
# # Saving the Fine-Tuned Lora Adaptors for Inferencing and Evaluation in Future

# %%
model.save_pretrained(f"/kaggle/working/fine-tuned-{model_id}-lora")

# %% [markdown]
# # Prediction or Test Inferencing on the Fine-Tuned Model

# %%
EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
# Setting the model for inference
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN


# generating response and cleaning it
def get_raw_response(instruction, input_text):
    inputs = tokenizer(
        [
            alpaca_prompt.format(
                f"{instruction}", # instruction
                f"{input_text}", # input
                "", # output - blank for generation!
            )
        ], return_tensors="pt").to("cuda")

    outputs = model.generate(**inputs, max_new_tokens=16, use_cache=True)
    raw_response = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return raw_response[0]

def get_response(instruction, input_text):
    raw_response = get_raw_response(instruction=instruction, input_text=input_text)
    # Extract Response from raw_response and return it as a string
    response = raw_response.split("### Response:\n")[1].strip()
    return response

# demo
instruction = ("You're an Advanced Medical Chatbot - Chatbot Dr. MCX, so assume yourself as a Healthcare Professional "
               "whose job is to listen to the Patient's query or symptoms and predict the underlying Health Problem the patient is suffering. "
               "Carefully listen to the Patient's query or symptoms and output only the Identified Health Problem in the following format: "
               "Identified Health Problem : [Health Problem Identified by you].")
input_text = "Patient's query or symptoms : skin rash, blackheads, scarring"

print(get_response(instruction=instruction, input_text=input_text))
# Out:
# Identified Health Problem : Acne Aesthetic Disease  Acne, also known

# %%
# Function to generate prediction using get_response function
def generate_prediction(row):
    instruction = row['instruction']
    input_text = row['input']
    prediction = get_response(instruction=instruction, input_text=input_text)
    print(f'{model_type} {model_id} prediction ::--> ', prediction)
    return prediction

# Function to generate prediction using get_response function
def generate_prediction_chunk(chunk, batch_index, i):
    chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
    
    # Create the directory if it doesn't exist
    output_dir = '/kaggle/working/output/'
    os.makedirs(output_dir, exist_ok=True)

    # Define the file path
    output_file = os.path.join(output_dir, f'predictions-{model_id}-{model_type}_batch_{batch_index}_i={i}.csv')
    chunk.to_csv(output_file, index=False)

# Load the test.csv file
test_df = pd.read_csv('/kaggle/working/test_dataset/transformed_test_primary.csv')

# Apply the generate_prediction_chunk function to create the prediction column in batches
batch_size = 100
for i in range(0, len(test_df), batch_size):
    chunk = test_df.iloc[i:i+batch_size]
    generate_prediction_chunk(chunk, i // batch_size, i)
# Out:
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vert
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vert
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : (vertigo) Paroymsal Positional Vert
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne Acdne
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne Aids Psoriasis Psoriasis Psoriasis Ps
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne Rosacea
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne Acdne
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne Aupcarcinosa
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne Aupenile Acne Vulgaris
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne Vulgaris
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne Aids Psoriasis Psoriasis Aids Ps
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Acne
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Aids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Aids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Alcoholic Hepatitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Asthma Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Eye Inflammation
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Rhinitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Asthma Bronchial Asthma Allerg
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Asthma Bronchitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Eye Inflammation
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Rhinitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Rhinitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Asthma Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy
#
# Allergies can cause a range of
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Eye Inflammation
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Eyelid Inflammation
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Anemia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Appendicitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In Fem
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma Attack
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bursitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cancer
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Celiac Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Cancer
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# /tmp/ipykernel_23/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Cervical Spondylosis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Of Pregnancy (ccp)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Of Pregnancy
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis Of Pregnancy (ccp)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chronic Cholestasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Heart Failure
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Common Cold
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dementia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dengue Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Depression
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# /tmp/ipykernel_23/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes 2 Type Diabetes 2 Type diabetes often doesn
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes 2 Type Diabetes 2 type diabetes is a
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes 1 Type 1 diabetes symptoms vary from person
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes Type 1
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes  Type 2 (Dmt 2)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes Type 2
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes Type 2
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes 1 Type Diabetes 1 Type diabetes usually develops
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes Type 2
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes 1.0
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes  Type 2 (adult) (diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes 204x001 - Diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diarrhea (loose, watery stools)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemmorhoids(piles)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids (Internal And External)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids (Internal And External)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Dimorphic Hemorrhoids
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction Diabetes Type 2 Diabetes Type 2 diabetes
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Thrombocytopenia And
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Diabetes 2 Type
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Ebfil (dracne)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Epilepsy Seizures And Epilepsy Signs
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Erectile Dysfunction (ed)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fibromyalgia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Flu
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Food Poisoning
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Fungal Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gallstones
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroenteritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroenteritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease Gerd G
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Allergy Rhinitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# /tmp/ipykernel_23/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease GERD
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease (gerd
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease Gerd
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gastroesophageal Reflux Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gerd Disease (Gastroesophageal Reflux
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gerd Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Gerd Disease (Gastroesophageal Reflux
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Glaucoma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Heart Attack
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Heat Stroke
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Heart Attack
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis A
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis A
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis A
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis A
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis B
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis B
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis B
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis B
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis C
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis C
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis C
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis D
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis D
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis D
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis D
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis E
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis E
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis E
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hepatitis E
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypertension
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hyperthyroidism
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hyperthyroidism
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hyperthyroidism
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hyperthyroidism
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypoglycemia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypoglycemia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypoglycemia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypoglycemia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypothyroidism
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypothyroidism
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypothyroidism
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Hypothyroidism
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Impetigo
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# /tmp/ipykernel_23/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Jaundice
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Lung Cancer
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Rheumatoid Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Malaria
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Measles
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bacterial Meningitis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine With Aura
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine With Aura
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine With Aura
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine With Aura
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine With Aura
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Migraine
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Osteoarthristis (骨关节炎)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Osteoarthristis (pronounced ao-s
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Osteoarthristis (bone joint)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Paralysis (brain Hemorrhage)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Paralysis (brain Hemorrhage)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Diseae
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Diseae
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Diseae
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peripheral Artery Disease Paad Paa D Paa
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# /tmp/ipykernel_23/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Bronchial Asthma
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Pneumonia
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Prostate Cancer
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Psoriasis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Chicken Pox
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Rabies
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Rheumatoid Arthritis
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Food Poisoning
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Shingles
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Peptic Ulcer Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Stroke
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Thyroid Cancer
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Tuberculosis (tb)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Tuberculosis (TB)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Tuberculosis (TB) Disease
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Drug Reaction With Eosinophilia And Systemic Symptoms
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid Fever
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Typhoid
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Colorectal Cancer (Colon Cancer)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In Women
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In Women
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In Women
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In Women
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection Utis Uti
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In Women
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti) In Women
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection (uti)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Urinary Tract Infection
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# /tmp/ipykernel_23/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins In Leg Varicose veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Varicose Veins
# fine-tuned Qwen2-7B-Instruct prediction ::-->  Identified Health Problem : Balanitis And Balanoposthitis In
# /tmp/ipykernel_23/1946869621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['prediction'] = chunk.apply(generate_prediction, axis=1)

# %%
import os
import pandas as pd

# Directory containing the CSV files
directory = '/kaggle/working/output/'

# List of file names to merge
file_names = [
    f"predictions-{model_id}-{model_type}_batch_0_i=0.csv",
    f"predictions-{model_id}-{model_type}_batch_1_i=100.csv",
    f"predictions-{model_id}-{model_type}_batch_2_i=200.csv",
    f"predictions-{model_id}-{model_type}_batch_3_i=300.csv",
    f"predictions-{model_id}-{model_type}_batch_4_i=400.csv",
    f"predictions-{model_id}-{model_type}_batch_5_i=500.csv",
    f"predictions-{model_id}-{model_type}_batch_6_i=600.csv"
]

# Initialize an empty DataFrame to store the merged data
merged_df = pd.DataFrame()

# Merge the CSV files in sequence
for file_name in file_names:
    file_path = os.path.join(directory, file_name)
    df = pd.read_csv(file_path)
    merged_df = pd.concat([merged_df, df], ignore_index=True)
merged_df = merged_df[['output','prediction','input','instruction']]

# Create the directory if it doesn't exist
output_dir = '/kaggle/working/results/'
os.makedirs(output_dir, exist_ok=True)

# Define the file path
output_file = os.path.join(output_dir, f"predictions-{model_id}-{model_type}-output.csv")

# Save the merged DataFrame to a new CSV file
merged_df.to_csv(output_file, index=False)
